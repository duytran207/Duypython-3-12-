# %% [markdown]
# <a href="https://colab.research.google.com/github/duytran207/Duypython-3-12-/blob/main/DuyT(3_12).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
a = float(input("a"))
b = float(input("b"))
c = float(input("c"))
if a == 0:
    if b == 0:
        if c == 0:
           print("pt vô số nghiệm")
        else:
           print("pt vô nghiệm")
    else:
         x = -c / b
         print("pt bậc nhất, nghiệm x=")
else:
     delta = b**2 - 4*a*c

     if delta > 0:
         x1 = (-b + math.sqrt(delta)) / (2*a)
         x2 = (-b - math.sqrt(delta)) / (2*a)
         print("pt có 2 nghiệm phân biệt:")
         print("x1 =", x1)
         print("x2 =", x2)
     elif delta == 0:
         x = -b/ (2*a)
         print("pt có nghiệm kép x =", x)
     else:
          print("pt vô nghiệm trong tập số thực")
# Out:
# a14
# b116
# c4
# pt có 2 nghiệm phân biệt:
# x1 = -0.03462747298616975
# x2 = -8.251086812728117
