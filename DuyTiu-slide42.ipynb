# %% [markdown]
# <a href="https://colab.research.google.com/github/duytran207/Duypython-3-12-/blob/main/DuyTiu-slide42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("n = "))
print(n)

s = 0
i = 2
chuoi = ""
while i < n:
    s += i
    chuoi += str(i) + " + "
    i += 2
print(f"the sum of 1 to {chuoi} is {s}")
# Out:
# n = 20
# 20
# the sum of 1 to 2 + 4 + 6 + 8 + 10 + 12 + 14 + 16 + 18 +  is 90
